# %% [markdown]
# # OpenCV. Техническое зрение робота

# %% [markdown]
# ## 1. ⚡ Основы компьютерного зрения

# %% [markdown]
# Компьютерное зрение - это область искусственного интеллекта, которая занимается обработкой и анализом изображений. Основной целью компьютерного зрения является получение информации из изображений и использование ее для принятия решений.
#
# Методы
#
# - `cv2.imread()`: чтение изображения из файла
#
#   - `filename`: Имя файла, из которого нужно прочитать изображение. Это может быть строка или байтовая строка.
#   - `flags`: Необязательный флаг, который указывает цветовой формат изображения. Возможные значения:
#   `cv2.IMREAD_COLOR`: Загружает изображение в цветовом формате BGR (по умолчанию).
#   `cv2.IMREAD_GRAYSCALE`: Загружает изображение в формате оттенков серого.
#   `cv2.IMREAD_UNCHANGED`: Загружает изображение в его исходном формате.
#   - Возвращает: 3-мерный массив `NumPy`, представляющий изображение.
#
#
# - `cv2.imshow()`: вывод изображения на экран
# - `cv2.waitKey()`: ожидание нажатия клавиши
#
#   `delay` - время ожидания нажатия клавиши в миллисекундах. Если `delay` равен 0, функция будет ожидать бесконечно.
#
# - `cv2.destroyAllWindows()`: закрытие всех окон

# %%
import cv2

img = cv2.imread('../assets/opencv/opencv_img.png')
cv2.imshow('Imageeee', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## ⚡ 1.2. Создание изображений
#
# Изображения можно создавать с помощью библиотеки NumPy.
#
# Методы:
#
# - `np.zeros()`: создание массива нулей
# - `np.full()`: создание массива с заданным значением

# %%
import numpy as np
import cv2

# Создание черного изображения размером 200x200
black_img = np.zeros((200, 200, 3), np.uint8)

# Создание белого изображения размером 200x200
blue_img = np.full((200, 200, 3), (255, 0, 0), np.uint8)

# Вывод изображения на экран
cv2.imshow('Black image', black_img)
cv2.imshow('Blue image', blue_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## ⚡ 1.3. Фильтры изображений
# Фильтры изображений используются для обработки изображений и удаления шума.
#
# - `cv2.blur()` - Простое размытие изображения
# Параметры:
#   - `src`: исходное изображение
#   - `ksize`: размер ядра размытия (например, (5, 5) для размытия 5x5 пикселей)
# Возвращает: размытое изображение
# Пример: cv2.blur(img, (5, 5))
#
# - `cv2.medianBlur()` - Медианный фильтр
# Параметры:
#   - `src`: исходное изображение
#   - `ksize`: размер ядра медианного фильтра (например, 5 для медианного фильтра 5x5 пикселей)
# Возвращает: изображение после применения медианного фильтра
# Пример: cv2.medianBlur(img, 5)
#
# - `cv2.GaussianBlur()` - Размытие по Гауссу
# Параметры:
#   - `src`: исходное изображение
#   - `ksize`: размер ядра размытия по Гауссу (например, (5, 5) для размытия 5x5 пикселей)
#   - `sigmaX`: стандартное отклонение по оси X (по умолчанию 0)
#   - `sigmaY`: стандартное отклонение по оси Y (по умолчанию 0)
# Возвращает: размытое изображение

# %%
import cv2

img = cv2.imread('../assets/opencv/blur_img.png')

# Простое размытие изображения
blurred_img = cv2.blur(img, (5, 5))

# Медианный фильтр
median_blurred_img = cv2.medianBlur(img, 5)

# Размытие по Гауссу
gaussian_blurred_img = cv2.GaussianBlur(img, (5, 5), 0)

# Вывод изображений на экран
cv2.imshow('Original', img)
cv2.imshow('Blurred', blurred_img)
cv2.imshow('Median Blurred', median_blurred_img)
cv2.imshow('Gaussian Blurred', gaussian_blurred_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# > 🦾 Давайте теперь сравним, как же метод фильтрации дает максимальный результат? Поиграйтесь с аргументами каждого фильтра и постарайтесь добиться наибольшего размытия на итоговом изображении

# %% [markdown]
# ## 1.4. Сглаживание изображений
# Двусторонний фильтр - это нелинейный фильтр, который уменьшает шум в изображении, сохраняя при этом края. Он работает, вычисляя взвешенную сумму соседних пикселей, где веса зависят от разницы в цвете и пространственном расстоянии между пикселями.
# Метод `cv2.bilateralFilter()` применяет двусторонний фильтр к изображению, чтобы уменьшить шум и сохранить края.
#
# Аргументы:
# - `src`: исходное изображение.
# - `d`: диаметр соседства пикселей, используемых для вычисления фильтра.
# - `sigmaColor`: стандартное отклонение цвета в пространстве цвета.
# - `sigmaSpace`: стандартное отклонение координат в пространстве координат.

# %%
import cv2

img = cv2.imread('../assets/opencv/blur_img.png')

# Двусторонний фильтр
bilateral_filtered_img = cv2.bilateralFilter(img, 50, 50, 50)

# Вывод изображений на экран
cv2.imshow('Original', img)
cv2.imshow('Bilateral Filtered', bilateral_filtered_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[17], line 6
#       3 img = cv2.imread('../assets/opencv/blur_img.png')
#       5 # Двусторонний фильтр
# ----> 6 bilateral_filtered_img = cv2.bilateralFilter(img, 50, 50, 50)
#       8 # Вывод изображений на экран
#       9 cv2.imshow('Original', img)
#
# error: OpenCV(4.2.0) ../modules/imgproc/src/bilateral_filter.dispatch.cpp:166: error: (-215:Assertion failed) (src.type() == CV_8UC1 || src.type() == CV_8UC3) && src.data != dst.data in function 'bilateralFilter_8u'

# %% [markdown]
# > 🦾 Постарайтесь, используя метод `bilateralFilter` максимально сгладить исходное изображение

# %% [markdown]
# ## ⚡ 1.5. Обработка изображений в реальном времени
# Обработка изображений в реальном времени - это процесс обработки изображений в режиме реального времени, например, с помощью камеры.
#
# Методы
#
# - `cv2.VideoCapture()`: чтение видеопотока из файла или камеры
# - `cv2.imshow()`: отображение изображения в окне
# - `cv2.waitKey()`: ожидание нажатия клавиши

# %%
import cv2

FindCam = []
for i in range(100):
    try:
        cap = cv2.VideoCapture(i)
        if cap is not None and cap.isOpened():
            FindCam.append(i)
    except:
        pass
print(str(FindCam))

# # Чтение видеопотока из камеры
# cap = cv2.VideoCapture(0)

# while True:
#     # Чтение кадра из видеопотока
#     ret, frame = cap.read()

#     # Обработка кадра
#     #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

#     # Отображение кадра
#     cv2.imshow('Video frame', frame)

#     # Ожидание нажатия клавиши
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break



# Закрытие окна

cap.release()    
cv2.destroyAllWindows()
# Out:
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src364 reported: Cannot identify device '/dev/video0'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (935) open OpenCV | GStreamer warning: Cannot query video position: status=0, value=-1, duration=-1
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src366 reported: Device '/dev/video2' is not a capture device.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src367 reported: Cannot identify device '/dev/video3'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video3): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src368 reported: Cannot identify device '/dev/video4'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video4): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src369 reported: Cannot identify device '/dev/video5'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video5): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src370 reported: Cannot identify device '/dev/video6'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video6): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src371 reported: Cannot identify device '/dev/video7'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video7): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src372 reported: Cannot identify device '/dev/video8'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video8): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src373 reported: Cannot identify device '/dev/video9'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video9): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src374 reported: Cannot identify device '/dev/video10'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video10): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src375 reported: Cannot identify device '/dev/video11'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video11): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src376 reported: Cannot identify device '/dev/video12'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video12): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src377 reported: Cannot identify device '/dev/video13'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video13): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src378 reported: Cannot identify device '/dev/video14'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video14): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src379 reported: Cannot identify device '/dev/video15'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video15): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src380 reported: Cannot identify device '/dev/video16'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video16): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src381 reported: Cannot identify device '/dev/video17'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video17): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src382 reported: Cannot identify device '/dev/video18'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video18): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src383 reported: Cannot identify device '/dev/video19'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video19): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src384 reported: Cannot identify device '/dev/video20'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video20): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src385 reported: Cannot identify device '/dev/video21'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video21): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src386 reported: Cannot identify device '/dev/video22'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video22): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src387 reported: Cannot identify device '/dev/video23'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video23): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src388 reported: Cannot identify device '/dev/video24'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video24): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src389 reported: Cannot identify device '/dev/video25'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video25): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src390 reported: Cannot identify device '/dev/video26'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video26): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src391 reported: Cannot identify device '/dev/video27'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video27): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src392 reported: Cannot identify device '/dev/video28'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video28): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src393 reported: Cannot identify device '/dev/video29'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video29): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src394 reported: Cannot identify device '/dev/video30'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video30): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src395 reported: Cannot identify device '/dev/video31'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video31): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src396 reported: Cannot identify device '/dev/video32'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video32): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src397 reported: Cannot identify device '/dev/video33'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video33): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src398 reported: Cannot identify device '/dev/video34'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video34): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src399 reported: Cannot identify device '/dev/video35'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video35): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src400 reported: Cannot identify device '/dev/video36'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video36): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src401 reported: Cannot identify device '/dev/video37'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video37): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src402 reported: Cannot identify device '/dev/video38'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video38): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src403 reported: Cannot identify device '/dev/video39'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video39): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src404 reported: Cannot identify device '/dev/video40'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video40): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src405 reported: Cannot identify device '/dev/video41'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video41): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src406 reported: Cannot identify device '/dev/video42'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video42): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src407 reported: Cannot identify device '/dev/video43'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video43): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src408 reported: Cannot identify device '/dev/video44'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video44): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src409 reported: Cannot identify device '/dev/video45'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video45): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src410 reported: Cannot identify device '/dev/video46'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video46): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src411 reported: Cannot identify device '/dev/video47'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video47): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src412 reported: Cannot identify device '/dev/video48'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video48): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src413 reported: Cannot identify device '/dev/video49'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video49): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src414 reported: Cannot identify device '/dev/video50'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video50): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src415 reported: Cannot identify device '/dev/video51'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video51): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src416 reported: Cannot identify device '/dev/video52'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video52): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src417 reported: Cannot identify device '/dev/video53'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video53): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src418 reported: Cannot identify device '/dev/video54'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video54): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src419 reported: Cannot identify device '/dev/video55'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video55): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src420 reported: Cannot identify device '/dev/video56'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video56): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src421 reported: Cannot identify device '/dev/video57'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video57): can't open camera by index
# [1]
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src422 reported: Cannot identify device '/dev/video58'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video58): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src423 reported: Cannot identify device '/dev/video59'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video59): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src424 reported: Cannot identify device '/dev/video60'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video60): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src425 reported: Cannot identify device '/dev/video61'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video61): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src426 reported: Cannot identify device '/dev/video62'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video62): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src427 reported: Cannot identify device '/dev/video63'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video63): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src428 reported: Cannot identify device '/dev/video64'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video64): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src429 reported: Cannot identify device '/dev/video65'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video65): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src430 reported: Cannot identify device '/dev/video66'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video66): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src431 reported: Cannot identify device '/dev/video67'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video67): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src432 reported: Cannot identify device '/dev/video68'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video68): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src433 reported: Cannot identify device '/dev/video69'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video69): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src434 reported: Cannot identify device '/dev/video70'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video70): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src435 reported: Cannot identify device '/dev/video71'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video71): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src436 reported: Cannot identify device '/dev/video72'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video72): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src437 reported: Cannot identify device '/dev/video73'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video73): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src438 reported: Cannot identify device '/dev/video74'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video74): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src439 reported: Cannot identify device '/dev/video75'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video75): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src440 reported: Cannot identify device '/dev/video76'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video76): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src441 reported: Cannot identify device '/dev/video77'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video77): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src442 reported: Cannot identify device '/dev/video78'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video78): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src443 reported: Cannot identify device '/dev/video79'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video79): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src444 reported: Cannot identify device '/dev/video80'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video80): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src445 reported: Cannot identify device '/dev/video81'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video81): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src446 reported: Cannot identify device '/dev/video82'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video82): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src447 reported: Cannot identify device '/dev/video83'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video83): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src448 reported: Cannot identify device '/dev/video84'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video84): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src449 reported: Cannot identify device '/dev/video85'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video85): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src450 reported: Cannot identify device '/dev/video86'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video86): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src451 reported: Cannot identify device '/dev/video87'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video87): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src452 reported: Cannot identify device '/dev/video88'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video88): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src453 reported: Cannot identify device '/dev/video89'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video89): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src454 reported: Cannot identify device '/dev/video90'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video90): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src455 reported: Cannot identify device '/dev/video91'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video91): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src456 reported: Cannot identify device '/dev/video92'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video92): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src457 reported: Cannot identify device '/dev/video93'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video93): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src458 reported: Cannot identify device '/dev/video94'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video94): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src459 reported: Cannot identify device '/dev/video95'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video95): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src460 reported: Cannot identify device '/dev/video96'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video96): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src461 reported: Cannot identify device '/dev/video97'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video97): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src462 reported: Cannot identify device '/dev/video98'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video98): can't open camera by index
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (1758) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module v4l2src463 reported: Cannot identify device '/dev/video99'.
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (888) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (480) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ WARN:0] global ../modules/videoio/src/cap_v4l.cpp (887) open VIDEOIO(V4L2:/dev/video99): can't open camera by index

# %% [markdown]
# ## 🐤 Работаем самостоятельно

# %% [markdown]
# ### 💬 Задача №1.1
#
# С помощью средств библиотек OpenCV и NumPy создайте изображение шахматной доски шириной в 5 клетки и длиной в 5 клеток. Пусть верхний левый квадрат будет фиолетовым, а его сосед справа - белым. Дальше чередуйте эти цвета в шахматном порядке. Сохраните его на компьютере (с помощью `imwrite`).

# %%
import numpy as np
import cv2

img = np.full((250, 250, 3), (155, 0, 155), np.uint8)
a = 0
b = 0

while a<5:
    while b<5:
        if (a+b)%2!=0:
            x = a*50
            y = b*50
            x2 = (a+1)*50
            y2 = (b+1)*50
            cv2.rectangle(img, (x, y), (x2,y2), (255, 255, 255),-1)
        b+=1
    a+=1
    b=0


#   cv2.rectangle(img, (51,0), (100,51), (255, 255, 255),-1)
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 💬 Задача №1.2
#
# Используя известные Вам фильтры, очистить изображение от белых точек
#
# <p align="center">
#   <img width="600" height="480" src="../assets/opencv/img_to_clean_opencv.png">
# </p>

# %%
import cv2

img = cv2.imread('/home/user_robohub5/ETU_RoboHub/assets/opencv/img_to_clean_opencv.png')

# Двусторонний фильтр
bilateral_filtered_img = cv2.bilateralFilter(img, 100, 100, 5000)

# Вывод изображений на экран
cv2.imshow('Original', img)
cv2.imshow('Bilateral Filtered', bilateral_filtered_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## ⚡ 2.1. Пороговая обработка
#
# Пороговая обработка - это процесс преобразования изображения в бинарное изображение, где пиксели имеют значения либо 0 (чёрный), либо 255 (белый). Это полезно для отделения объектов от фона.
#
# Методы
#
# - `cv2.threshold()`: порог к изображению
#   - `cv2.THRESH_BINARY`: бинарный порог
#   - `cv2.THRESH_BINARY_INV`: инверсный бинарный порог
#   - `cv2.THRESH_TRUNC`: обрезает значения пикселей выше порога
#   - `cv2.THRESH_TOZERO`: устанавливает значения пикселей ниже порога в 0
#   - `cv2.THRESH_TOZERO_INV`: устанавливает значения пикселей выше порога в 0

# %%
import cv2

img = cv2.imread('../assets/opencv/draw_contours.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Применение бинарного порога
_, thresh = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# Применение инверсного бинарного порога
_, thresh_inv = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)

# Отображение результатов
cv2.imshow('Original', img)
cv2.imshow('Threshold', thresh)
cv2.imshow('Threshold inv', thresh_inv)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 16
#      14 cv2.imshow('Threshold', thresh)
#      15 cv2.imshow('Threshold inv', thresh_inv)
# ---> 16 cv2.waitKey(0)
#      17 cv2.destroyAllWindows()
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# > 🦾 Посмотрите, как изменение аргументов в `cv2.threshold` влияет на преобразование исходного изображения в бинарное. Постарайтесь добиться максимального результата

# %% [markdown]
# ## ⚡ 2.2. Адаптивная пороговая обработка
#
# Адаптивная пороговая обработка - это процесс пороговой обработки изображения на основе локальных значений пикселей. Это полезно для изображений с переменными условиями освещения.
#
# Методы
#
# - `cv2.adaptiveThreshold()`:  адаптивный порог к изображению
# - `cv2.ADAPTIVE_THRESH_MEAN_C`: использует среднее значение соседних пикселей как порог
# - `cv2.ADAPTIVE_THRESH_GAUSSIAN_C`: использует взвешенную сумму соседних пикселей как порог

# %%
import cv2

# Чтение изображения
img = cv2.imread('../assets/opencv/shapes-small.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Применение адаптивного порога с использованием среднего значения
thresh_mean = cv2.adaptiveThreshold(img, 125, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 21, 2)

# Применение адаптивного порога с использованием взвешенной суммы
thresh_gaussian = cv2.adaptiveThreshold(img, 125, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)

# Отображение результатов
cv2.imshow('Original', img)
cv2.imshow('Adaptive thresh mean', thresh_mean)
cv2.imshow('Gaussian Adaptive thresh', thresh_gaussian)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# > 🦾 Посмотрите, как изменение аргументов в `cv2.adaptiveThreshold` влияет на преобразование исходного изображения. Постарайтесь добиться максимального результата

# %% [markdown]
# ## ⚡ 2.3. Обнаружение границ
# Обнаружение границ - это процесс нахождения границ между объектами на изображении.
#
# Методы
#
# - `cv2.Canny()`: применяет алгоритм обнаружения границ Кенни
# - `cv2.Sobel()`: применяет алгоритм обнаружения границ Собеля

# %%
import cv2

# Чтение изображения
img = cv2.imread('../assets/opencv/draw_contours.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Применение алгоритма обнаружения границ Кенни
edges_canny = cv2.Canny(img, 50, 150)

# Применение алгоритма обнаружения границ Собеля
edges_sobel = cv2.Sobel(img, cv2.CV_8U, 1, 0, ksize=5)

# Отображение результатов
cv2.imshow('Original', img)
cv2.imshow('Canny edge', edges_canny)
cv2.imshow('Sobel edge', edges_sobel)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# > 🦾 Посмотрите, как изменение аргументов в `cv2.Canny` и `cv2.Sobel` влияет на детекцию контуров на исходном изображение. Постарайтесь добиться максимального результата

# %% [markdown]
# ## ⚡ 2.4. Обнаружение контуров
#
# Обнаружение контуров - это процесс нахождения границ объектов на изображении.
#
# Методы
#
# - `cv2.findContours()`: находит контуры на изображении
# - `cv2.drawContours()`: рисует контуры на изображении

# %% [markdown]
# Параметры функции `cv2.findContours()`
#
# - `image`: изображение, на котором нужно найти контуры
# - `mode`: режим нахождения контуров (например, cv2.RETR_EXTERNAL для нахождения внешних контуров)
# - `method`: метод нахождения контуров (например, cv2.CHAIN_APPROX_SIMPLE для упрощения контуров)
#
# Параметры функции `cv2.drawContours()`
#
# -`image`: изображение, на котором нужно нарисовать контуры
# -`contours`: контуры, которые нужно нарисовать
# -`index`: индекс контура, который нужно нарисовать (например, -1 для рисования всех контуров)
# -`color`: цвет, которым нужно рисовать контуры
# -`thickness`: толщина контуров
#
# Примечания
#
# Функция `cv2.findContours()` возвращает список контуров и иерархию контуров.
# Функция `cv2.drawContours()` рисует контуры на изображении.

# %%
import cv2

# Чтение изображения
img = cv2.imread('../assets/opencv/shapes-small.jpg')

# Преобразование изображения в градации серого
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Применение пороговой обработки
_, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
# Нахождение контуров на изображении
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Рисование контуров на изображении
cv2.drawContours(img, contours, -1, (0, 0, 255), 2)

# Отображение результатов
cv2.imshow('Gray image original', gray)
cv2.imshow('Binary image', thresh)
cv2.imshow('Image with contours', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# > 🦾 Изменяя аргументы в `cv2.threshold` добейтесь того, чтобы каждый контур был выведен на итоговом изображении

# %% [markdown]
# ## ⚡ 2.5. Уже почти все...
#
# После того, как мы научились находить контуры на изображении, а также их выделять, остается последняя задача: научиться их обрабатывать. В этом нам поможет пара функций
#
# - `cv2.arcLength` - вычисляет длину контура или дуги.
#
#   - `curve`: контур или дуга, представленная как массив точек.
#   - `closed`: логический флаг, указывающий, является ли контур замкнутым.
#
# *Возвращаемое значение: длина контура или дуги.*
#
# - `cv2.contourArea` - вычисляет площадь контура.
#   - `contour`: контур, представленный как массив точек.
#   - `oriented`: логический флаг, указывающий, следует ли учитывать ориентацию контура при вычислении площади.
#
# *Возвращаемое значение: площадь контура.*
#
# - `cv2.boundingRect` - вычисляет ограничивающий прямоугольник контура.
#   - `array`: контур, представленный как массив точек.
#
# *Возвращаемое значение: координаты и размеры ограничивающего прямоугольника (x, y, w, h).*
#
# - `cv2.minEnclosingCircle` - вычисляет минимально вписывающий круг контура.
#   - `points`: контур, представленный как массив точек.
#
# *Возвращаемое значение: центр и радиус минимально вписывающего круга.*

# %%
import cv2
import numpy as np

# Создаем контур
contour = np.array([[[10, 10]], [[10, 50]], [[50, 50]], [[50, 10]]])

# Вычисляем длину контура
length = cv2.arcLength(contour, True)
print("Длина контура:", length)

# Вычисляем площадь контура
area = cv2.contourArea(contour)
print("Площадь контура:", area)

# Вычисляем ограничивающий прямоугольник контура
rect = cv2.boundingRect(contour)
print("Ограничивающий прямоугольник:", rect)

# Вычисляем минимально вписывающий круг контура
(center, radius) = cv2.minEnclosingCircle(contour)
print("Центр и радиус минимально вписывающего круга:", center, radius)
# Out:
# Длина контура: 160.0
# Площадь контура: 1600.0
# Ограничивающий прямоугольник: (10, 10, 41, 41)
# Центр и радиус минимально вписывающего круга: (30.0, 30.0) 28.28437042236328

# %% [markdown]
# ## 🐤 Работаем самостоятельно

# %% [markdown]
# ### 💬 Задание 2.1
#
# Найти и нарисовать контуры на следующем изображении, выделив при этом разными цветами каждую из фигур.
#
# <p align="center">
#   <img width="600" height="480" src="../assets/opencv/find_contours.png">
# </p>

# %%
import cv2
import random

img = cv2.imread('../assets/opencv/find_contours.png', cv2.IMREAD_GRAYSCALE)

contours, hierarhy  = cv2.findContours(img, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_NONE)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.drawContours(img, contours, -1, (0, 0, 255), 10)

x=0
for contour in contours:
    print()
    # print(contour[0][x])
    cv2.drawContours(img, contours, [x][0], (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)), 2)
    # cv2.drawContours(img, contours, [0][x], (255, 0, 0), 2)
    x+=1

cv2.imshow('Image with contours', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 💬 Задание 2.2
#
# Теперь немного усложним задачу: тебе нужно найти контуры на цветном изображении, выделить их и подписать распознанный цвет объекта
#
# <p align="center">
#   <img width="800" height="480" src="../assets/opencv/find_cubes.png">
# </p>

# %%
import cv2
import numpy as np

img = cv2.imread('../assets/opencv/find_cubes.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thresh = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 3, 2)
# cv2.imshow('thresh', thresh)
contours, _  = cv2.findContours(thresh, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_NONE)

maxS_id = -1
maxS = 0
array_s = []

for contour in contours:
    s = cv2.contourArea(contour)
    array_s.append(s)
    if maxS < cv2.contourArea(contour):
        maxS = cv2.contourArea(contour)

maxS_index = array_s.index(maxS)
contours.pop(maxS_index)

i=len(contours)-1
j=(len(contours)-1)/2
while i>j:
    contours.pop(i)
    i-=1

for contour in contours:
    M = cv2.moments(contour)
    cX = int(M["m10"] / M["m00"])
    cY = int(M["m01"] / M["m00"])
    # print(cX, cY)
    # cv2.circle(img, (cX, cY), 5, (255, 0, 0), 1, -1)
    color = np.array(cv2.split(img[cY,cX]), dtype=np.uint8)
    r, g, b = color.flatten()
    print(r, g, b)
    cv2.putText(img, '%d, %d, %d' % (r, g, b), (cX - 50, cY - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1)
        

    
  
for contour in contours:
    if cv2.contourArea(contour) < maxS: 
        cv2.drawContours(img, contour, -1, (255, 0, 0), 2)

cv2.imshow('Image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 168 287
# 0 255 0
# 493 248
# 255 128 0
# 377 84
# 0 255 255
# 121 87
# 0 0 255

# %% [markdown]
# ### 💬 Задание 2.3
#
# Последняя задача, которую тебе предстоит решить - сделать детекцию и классификацию контуров по цвету на видеопотоке, которое ты получаешь в веб-камеры. Для решения этой задачи тебе нужно применить все те знания, которые ты получил за сегодня
#
# ❗ Небольшая подсказка ❗
#
# Поскольку вы работаете с видеопотоком, то цвет нужно будет определять в каких-то границах (нижних и верхних). Для этого вам нужно создать словарь, например, `color_ranges`, в котором зададите границы с помощью массивов NumPy
#
# Нужно понимать, что кроме простейших объектов типа чисел и строк словари также могут хранить и более сложные объекты - те же списки, кортежи или другие словари. Вот небольшой пример словаря-базы данных 👇

# %%
users = {
    "Tom": {
        "phone": "+971478745",
        "email": "tom12@gmail.com"
    },
    "Bob": {
        "phone": "+876390444",
        "email": "bob@gmail.com",
        "skype": "bob123"
    }
}

# %% [markdown]
# В данном случае значение каждого элемента словаря в свою очередь представляет отдельный словарь.
#
# Для обращения к элементам вложенного словаря соответственно необходимо использовать два ключа

# %%
old_email = users["Tom"]["email"]
users["Tom"]["email"] = "supertom@gmail.com"
print(users["Tom"])     # { phone": "+971478745", "email": "supertom@gmail.com }
# Out:
# {'phone': '+971478745', 'email': 'supertom@gmail.com'}

# %% [markdown]
# 💪 Теперь мы точно уверены, что с последней задачей вы справитесь и готовы написать код

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(1)

while True:
    # Чтение кадра из видеопотока
    ret, img = cap.read()

    color = []

    img_red = cv2.inRange(img, (0, 0, 139), (128, 128, 240)) #цвета в gbr
    contours_red, _  = cv2.findContours(img_red, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    for cont in contours_red:
        if cv2.contourArea(cont) > 3000:
            x, y, w, h = cv2.boundingRect(cont)
            cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 255), 2)

    img_yel = cv2.inRange(img, (0, 165, 165), (150, 254, 255)) #цвета в gbr
    contours_yel, _  = cv2.findContours(img_yel, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    for cont in contours_yel:
        if cv2.contourArea(cont) > 3000:
            x, y, w, h = cv2.boundingRect(cont)
            cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 255), 2)

    img_gr = cv2.inRange(img, (0, 77, 9), (100, 255, 100)) #цвета в gbr
    contours_gr, _  = cv2.findContours(img_gr, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    for cont in contours_gr:
        if cv2.contourArea(cont) > 3000:
            x, y, w, h = cv2.boundingRect(cont)
            cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

    img_bl = cv2.inRange(img, (127,20,0), (255, 124, 108)) #цвета в gbr
    contours_bl, _  = cv2.findContours(img_bl, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    for cont in contours_bl:
        if cv2.contourArea(cont) > 3000:
            x, y, w, h = cv2.boundingRect(cont)
            cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

    # cv2.imshow('wow its red', img_red)
    cv2.imshow('wow it works!', img)

    # Ожидание нажатия клавиши
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
# Закрытие окна
cap.release()    
cv2.destroyAllWindows()
# Out:
# [ WARN:0] global ../modules/videoio/src/cap_gstreamer.cpp (935) open OpenCV | GStreamer warning: Cannot query video position: status=0, value=-1, duration=-1
